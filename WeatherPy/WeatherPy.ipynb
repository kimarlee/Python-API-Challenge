# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 585

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = query_url + city

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | roma
# Processing Record 2 of Set 1 | castillos
# Processing Record 3 of Set 1 | dahlonega
# Processing Record 4 of Set 1 | harper
# Processing Record 5 of Set 1 | la passe
# Processing Record 6 of Set 1 | dickinson
# Processing Record 7 of Set 1 | port-aux-francais
# Processing Record 8 of Set 1 | bethel
# Processing Record 9 of Set 1 | grytviken
# Processing Record 10 of Set 1 | port macquarie
# Processing Record 11 of Set 1 | aasiaat
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | ayorou
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | fort bragg
# Processing Record 16 of Set 1 | port mathurin
# Processing Record 17 of Set 1 | malanje
# Processing Record 18 of Set 1 | hawaiian paradise park
# Processing Record 19 of Set 1 | kawthoung
# City not found. Skipping...
# Processing Record 20 of Set 1 | chonchi
# Processing Record 21 of Set 1 | port elizabeth
# Processing Record 22 of Set 1 | stung treng
# Processing Record 23 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 24 of Set 1 | senanga
# Processing Record 25 of Set 1 | georgetown
# Processing Record 26 of Set 1 | intendente alvear
# Processing Record 27 of Set 1 | taghazout
# Processing Record 28 of Set 1 | talnakh
# Processing Record 29 of Set 1 | tralee
# Processing Record 30 of Set 1 | kirensk
# Processing Record 31 of Set 1 | adamstown
# Processing Record 32 of Set 1 | la'ie
# Processing Record 33 of Set 1 | suva
# Processing Record 34 of Set 1 | kirkwall
# Processing Record 35 of Set 1 | huntington
# Processing Record 36 of Set 1 | cabo san lucas
# Processing Record 37 of Set 1 | anadyr
# Processing Record 38 of Set 1 | remire-montjoly
# Processing Record 39 of Set 1 | kingston
# Processing Record 40 of Set 1 | les sables-d'olonne
# Processing Record 41 of Set 1 | waitangi
# Processing Record 42 of Set 1 | vinh
# Processing Record 43 of Set 1 | kotlas
# Processing Record 44 of Set 1 | falam
# Processing Record 45 of Set 1 | hermanus
# Processing Record 46 of Set 1 | nemuro
# Processing Record 47 of Set 1 | blackmans bay
# Processing Record 48 of Set 1 | vila velha
# Processing Record 49 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 50 of Set 1 | port augusta
# Processing Record 0 of Set 2 | ushuaia
# Processing Record 1 of Set 2 | laurel
# Processing Record 2 of Set 2 | filadelfia
# Processing Record 3 of Set 2 | stanley
# Processing Record 4 of Set 2 | invercargill
# Processing Record 5 of Set 2 | hancheng
# Processing Record 6 of Set 2 | san pedro pochutla
# Processing Record 7 of Set 2 | golhisar
# Processing Record 8 of Set 2 | gemena
# Processing Record 9 of Set 2 | antalaha
# Processing Record 10 of Set 2 | bontang
# Processing Record 11 of Set 2 | gereida
# Processing Record 12 of Set 2 | olonkinbyen
# Processing Record 13 of Set 2 | princeville
# Processing Record 14 of Set 2 | khandyga
# Processing Record 15 of Set 2 | puerto natales
# Processing Record 16 of Set 2 | udachny
# Processing Record 17 of Set 2 | howrah
# Processing Record 18 of Set 2 | sheridan
# Processing Record 19 of Set 2 | kailua-kona
# Processing Record 20 of Set 2 | janeng
# Processing Record 21 of Set 2 | st. john's
# Processing Record 22 of Set 2 | atafu village
# Processing Record 23 of Set 2 | mogocha
# Processing Record 24 of Set 2 | punta arenas
# Processing Record 25 of Set 2 | lewiston orchards
# Processing Record 26 of Set 2 | isafjordur
# Processing Record 27 of Set 2 | tasqala
# Processing Record 28 of Set 2 | thompson
# Processing Record 29 of Set 2 | as sulayyil
# Processing Record 30 of Set 2 | vorgashor
# Processing Record 31 of Set 2 | motygino
# Processing Record 32 of Set 2 | lompoc
# Processing Record 33 of Set 2 | hakui
# Processing Record 34 of Set 2 | puerto carreno
# Processing Record 35 of Set 2 | malango
# Processing Record 36 of Set 2 | nizhneudinsk
# Processing Record 37 of Set 2 | ilhabela
# Processing Record 38 of Set 2 | san patricio
# Processing Record 39 of Set 2 | bredasdorp
# Processing Record 40 of Set 2 | baise city
# Processing Record 41 of Set 2 | dinguiraye
# Processing Record 42 of Set 2 | iskateley
# Processing Record 43 of Set 2 | hithadhoo
# Processing Record 44 of Set 2 | vilyuchinsk
# Processing Record 45 of Set 2 | broome
# Processing Record 46 of Set 2 | horta
# Processing Record 47 of Set 2 | thunder bay
# Processing Record 48 of Set 2 | papatowai
# Processing Record 49 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 0 of Set 3 | kayenta
# Processing Record 1 of Set 3 | butajira
# Processing Record 2 of Set 3 | nhamunda
# Processing Record 3 of Set 3 | yellowknife
# Processing Record 4 of Set 3 | naze
# Processing Record 5 of Set 3 | mazagao
# Processing Record 6 of Set 3 | semnan
# Processing Record 7 of Set 3 | ancud
# Processing Record 8 of Set 3 | qaqortoq
# Processing Record 9 of Set 3 | dudinka
# Processing Record 10 of Set 3 | ban dan lan hoi
# Processing Record 11 of Set 3 | la ronge
# Processing Record 12 of Set 3 | igarka
# Processing Record 13 of Set 3 | porto velho
# Processing Record 14 of Set 3 | longyearbyen
# Processing Record 15 of Set 3 | sweet home
# Processing Record 16 of Set 3 | nova sintra
# Processing Record 17 of Set 3 | blankenberge
# Processing Record 18 of Set 3 | mount gambier
# Processing Record 19 of Set 3 | ilulissat
# Processing Record 20 of Set 3 | manadhoo
# Processing Record 21 of Set 3 | chernyshevskiy
# Processing Record 22 of Set 3 | mangai
# Processing Record 23 of Set 3 | utrik
# Processing Record 24 of Set 3 | tsiolkovskiy
# City not found. Skipping...
# Processing Record 25 of Set 3 | bel ombre
# Processing Record 26 of Set 3 | holualoa
# Processing Record 27 of Set 3 | west island
# Processing Record 28 of Set 3 | nguigmi
# Processing Record 29 of Set 3 | pokrovsk
# Processing Record 30 of Set 3 | mukalla
# Processing Record 31 of Set 3 | edinburgh of the seven seas
# Processing Record 32 of Set 3 | namtsy
# Processing Record 33 of Set 3 | djenne
# Processing Record 34 of Set 3 | yuzhno-kurilsk
# Processing Record 35 of Set 3 | saipan
# Processing Record 36 of Set 3 | tiksi
# Processing Record 37 of Set 3 | ust-nera
# Processing Record 38 of Set 3 | mulki
# Processing Record 39 of Set 3 | san jorge
# Processing Record 40 of Set 3 | san antonio de pale
# Processing Record 41 of Set 3 | weno
# Processing Record 42 of Set 3 | essaouira
# Processing Record 43 of Set 3 | wailua homesteads
# Processing Record 44 of Set 3 | puerto aysen
# Processing Record 45 of Set 3 | cockburn town
# Processing Record 46 of Set 3 | hasaki
# Processing Record 47 of Set 3 | changping
# Processing Record 48 of Set 3 | laguna
# Processing Record 49 of Set 3 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 0 of Set 4 | jamestown
# Processing Record 1 of Set 4 | jianshui
# Processing Record 2 of Set 4 | pangody
# Processing Record 3 of Set 4 | katabu
# Processing Record 4 of Set 4 | grandview
# Processing Record 5 of Set 4 | kaedi
# Processing Record 6 of Set 4 | greymouth
# Processing Record 7 of Set 4 | flin flon
# Processing Record 8 of Set 4 | walvis bay
# Processing Record 9 of Set 4 | enewetak
# Processing Record 10 of Set 4 | bilibino
# Processing Record 11 of Set 4 | tazovsky
# Processing Record 12 of Set 4 | portland
# Processing Record 13 of Set 4 | cairns city
# City not found. Skipping...
# Processing Record 14 of Set 4 | tete
# Processing Record 15 of Set 4 | kodiak
# Processing Record 16 of Set 4 | arraial do cabo
# Processing Record 17 of Set 4 | talakan
# Processing Record 18 of Set 4 | puerto baquerizo moreno
# Processing Record 19 of Set 4 | donauworth
# Processing Record 20 of Set 4 | alofi
# Processing Record 21 of Set 4 | usinsk
# Processing Record 22 of Set 4 | pisco
# Processing Record 23 of Set 4 | samana
# Processing Record 24 of Set 4 | duong dong
# Processing Record 25 of Set 4 | usogorsk
# Processing Record 26 of Set 4 | kayyerkan
# Processing Record 27 of Set 4 | san sebastian de la gomera
# Processing Record 28 of Set 4 | auki
# Processing Record 29 of Set 4 | dunedin
# Processing Record 30 of Set 4 | hauterive
# Processing Record 31 of Set 4 | nouadhibou
# Processing Record 32 of Set 4 | mpika
# Processing Record 33 of Set 4 | pattani
# Processing Record 34 of Set 4 | constantia
# Processing Record 35 of Set 4 | chita
# Processing Record 36 of Set 4 | lebu
# Processing Record 37 of Set 4 | amga
# Processing Record 38 of Set 4 | seogwipo
# City not found. Skipping...
# Processing Record 39 of Set 4 | margaret river
# Processing Record 40 of Set 4 | ishigaki
# Processing Record 41 of Set 4 | irymple
# Processing Record 42 of Set 4 | miranda
# Processing Record 43 of Set 4 | nova vicosa
# Processing Record 44 of Set 4 | inhambane
# Processing Record 45 of Set 4 | nizhnyaya poyma
# Processing Record 46 of Set 4 | itoman
# Processing Record 47 of Set 4 | vila franca do campo
# Processing Record 48 of Set 4 | new norfolk
# Processing Record 49 of Set 4 | kokrajhar
# Processing Record 0 of Set 5 | shache
# Processing Record 1 of Set 5 | hami
# Processing Record 2 of Set 5 | fortuna
# Processing Record 3 of Set 5 | kayangel
# Processing Record 4 of Set 5 | lamu
# Processing Record 5 of Set 5 | wotho
# Processing Record 6 of Set 5 | barcelos
# Processing Record 7 of Set 5 | lorengau
# Processing Record 8 of Set 5 | al ghayzah
# Processing Record 9 of Set 5 | minas de marcona
# Processing Record 10 of Set 5 | kish
# Processing Record 11 of Set 5 | choma
# Processing Record 12 of Set 5 | bokoro
# Processing Record 13 of Set 5 | khovd
# Processing Record 14 of Set 5 | kalmunai
# Processing Record 15 of Set 5 | pandan
# Processing Record 16 of Set 5 | kununurra
# Processing Record 17 of Set 5 | toropets
# Processing Record 18 of Set 5 | iqaluit
# Processing Record 19 of Set 5 | akonolinga
# Processing Record 20 of Set 5 | barmer
# Processing Record 21 of Set 5 | santana
# Processing Record 22 of Set 5 | sitangkai
# Processing Record 23 of Set 5 | rupea
# Processing Record 24 of Set 5 | lata
# Processing Record 25 of Set 5 | taulaga
# Processing Record 26 of Set 5 | ad dilam
# Processing Record 27 of Set 5 | bridgewater
# Processing Record 28 of Set 5 | chulakkurgan
# Processing Record 29 of Set 5 | lihue
# Processing Record 30 of Set 5 | kone
# Processing Record 31 of Set 5 | altus
# Processing Record 32 of Set 5 | aykhal
# Processing Record 33 of Set 5 | sirjan
# Processing Record 34 of Set 5 | katsuren-haebaru
# Processing Record 35 of Set 5 | harnai
# Processing Record 36 of Set 5 | shimoda
# Processing Record 37 of Set 5 | waupaca
# Processing Record 38 of Set 5 | verkhniy ufaley
# Processing Record 39 of Set 5 | ampanihy
# Processing Record 40 of Set 5 | port alfred
# Processing Record 41 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 42 of Set 5 | college
# Processing Record 43 of Set 5 | coyhaique
# Processing Record 44 of Set 5 | guozhen
# Processing Record 45 of Set 5 | bulata
# Processing Record 46 of Set 5 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 47 of Set 5 | buritizeiro
# Processing Record 48 of Set 5 | rio grande
# Processing Record 49 of Set 5 | itaituba
# Processing Record 0 of Set 6 | beyneu
# Processing Record 1 of Set 6 | nar'yan-mar
# Processing Record 2 of Set 6 | san juan de miraflores
# Processing Record 3 of Set 6 | madera
# Processing Record 4 of Set 6 | fannuj
# City not found. Skipping...
# Processing Record 5 of Set 6 | rongelap
# Processing Record 6 of Set 6 | haiku-pauwela
# Processing Record 7 of Set 6 | selfoss
# Processing Record 8 of Set 6 | penzance
# Processing Record 9 of Set 6 | qaisumah
# Processing Record 10 of Set 6 | pemangkat
# Processing Record 11 of Set 6 | kulia village
# City not found. Skipping...
# Processing Record 12 of Set 6 | sishilichengzi
# City not found. Skipping...
# Processing Record 13 of Set 6 | luderitz
# Processing Record 14 of Set 6 | cestos city
# Processing Record 15 of Set 6 | rieti
# Processing Record 16 of Set 6 | whitehorse
# Processing Record 17 of Set 6 | dolinsk
# Processing Record 18 of Set 6 | spinea-orgnano
# Processing Record 19 of Set 6 | yaya
# Processing Record 20 of Set 6 | freetown
# Processing Record 21 of Set 6 | ahau
# City not found. Skipping...
# Processing Record 22 of Set 6 | egilsstadir
# Processing Record 23 of Set 6 | kokopo
# Processing Record 24 of Set 6 | novodvinsk
# Processing Record 25 of Set 6 | nuuk
# Processing Record 26 of Set 6 | kavaratti
# Processing Record 27 of Set 6 | labytnangi
# Processing Record 28 of Set 6 | sitka
# Processing Record 29 of Set 6 | port lincoln
# Processing Record 30 of Set 6 | cooma
# Processing Record 31 of Set 6 | andovoranto
# Processing Record 32 of Set 6 | alakurtti
# Processing Record 33 of Set 6 | badger
# Processing Record 34 of Set 6 | ugoofaaru
# Processing Record 35 of Set 6 | lincheng
# Processing Record 36 of Set 6 | avarua
# Processing Record 37 of Set 6 | songea
# Processing Record 38 of Set 6 | jagtial
# Processing Record 39 of Set 6 | kourou
# Processing Record 40 of Set 6 | kavieng
# Processing Record 41 of Set 6 | crane
# Processing Record 42 of Set 6 | bubaque
# Processing Record 43 of Set 6 | antsiranana
# Processing Record 44 of Set 6 | bejubang dua
# City not found. Skipping...
# Processing Record 45 of Set 6 | baymak
# Processing Record 46 of Set 6 | turinskaya sloboda
# Processing Record 47 of Set 6 | saint-philippe
# Processing Record 48 of Set 6 | nogliki
# Processing Record 49 of Set 6 | santa elena de uairen
# Processing Record 0 of Set 7 | alice springs
# Processing Record 1 of Set 7 | ghat
# Processing Record 2 of Set 7 | cabrobo
# Processing Record 3 of Set 7 | ljusdal
# Processing Record 4 of Set 7 | valle de la pascua
# Processing Record 5 of Set 7 | pathein
# Processing Record 6 of Set 7 | coronel marcelino mariduena
# Processing Record 7 of Set 7 | chui
# Processing Record 8 of Set 7 | nakhon si thammarat
# Processing Record 9 of Set 7 | takamaka
# City not found. Skipping...
# Processing Record 10 of Set 7 | les avirons
# Processing Record 11 of Set 7 | serowe
# Processing Record 12 of Set 7 | mildura
# Processing Record 13 of Set 7 | najran
# Processing Record 14 of Set 7 | dubbo
# Processing Record 15 of Set 7 | blantyre
# Processing Record 16 of Set 7 | sovetskaya gavan'
# Processing Record 17 of Set 7 | kudahuvadhoo
# Processing Record 18 of Set 7 | kodinsk
# Processing Record 19 of Set 7 | chongjin
# Processing Record 20 of Set 7 | quartu sant'elena
# Processing Record 21 of Set 7 | xinxiang
# Processing Record 22 of Set 7 | sisimiut
# Processing Record 23 of Set 7 | taber
# Processing Record 24 of Set 7 | seydi
# Processing Record 25 of Set 7 | mushie
# Processing Record 26 of Set 7 | cidade velha
# Processing Record 27 of Set 7 | alotau
# Processing Record 28 of Set 7 | jinka
# Processing Record 29 of Set 7 | rikaze
# Processing Record 30 of Set 7 | sultanah
# Processing Record 31 of Set 7 | abadan
# Processing Record 32 of Set 7 | keelung
# Processing Record 33 of Set 7 | sinabang
# Processing Record 34 of Set 7 | belmonte
# Processing Record 35 of Set 7 | mishkino
# Processing Record 36 of Set 7 | kamaishi
# Processing Record 37 of Set 7 | santa ana
# Processing Record 38 of Set 7 | afaahiti
# Processing Record 39 of Set 7 | boca do acre
# Processing Record 40 of Set 7 | igrim
# Processing Record 41 of Set 7 | qamdo
# Processing Record 42 of Set 7 | puerto deseado
# Processing Record 43 of Set 7 | niquelandia
# Processing Record 44 of Set 7 | afif
# Processing Record 45 of Set 7 | jolo
# Processing Record 46 of Set 7 | barhi
# Processing Record 47 of Set 7 | yamba
# City not found. Skipping...
# Processing Record 48 of Set 7 | greenville
# Processing Record 49 of Set 7 | ukmerge
# Processing Record 0 of Set 8 | plettenberg bay
# Processing Record 1 of Set 8 | vilyuysk
# Processing Record 2 of Set 8 | tabuk
# Processing Record 3 of Set 8 | bardai
# Processing Record 4 of Set 8 | fale old settlement
# Processing Record 5 of Set 8 | al jahra'
# Processing Record 6 of Set 8 | manturovo
# Processing Record 7 of Set 8 | north bend
# Processing Record 8 of Set 8 | goundam
# Processing Record 9 of Set 8 | bonthe
# Processing Record 10 of Set 8 | mossel bay
# Processing Record 11 of Set 8 | papao
# Processing Record 12 of Set 8 | hayma'
# City not found. Skipping...
# Processing Record 13 of Set 8 | wladyslawowo
# Processing Record 14 of Set 8 | bamboo flat
# Processing Record 15 of Set 8 | riyadh
# Processing Record 16 of Set 8 | corner brook
# Processing Record 17 of Set 8 | rehoboth
# Processing Record 18 of Set 8 | turpan
# Processing Record 19 of Set 8 | namdrik
# Processing Record 20 of Set 8 | shakawe
# Processing Record 21 of Set 8 | gering
# Processing Record 22 of Set 8 | luwuk
# Processing Record 23 of Set 8 | napier
# Processing Record 24 of Set 8 | kazlu ruda
# Processing Record 25 of Set 8 | ribeira grande
# Processing Record 26 of Set 8 | sorsk
# Processing Record 27 of Set 8 | linxia chengguanzhen
# Processing Record 28 of Set 8 | karagandy
# Processing Record 29 of Set 8 | vadso
# Processing Record 30 of Set 8 | shingu
# Processing Record 31 of Set 8 | praia da vitoria
# Processing Record 32 of Set 8 | opuwo
# Processing Record 33 of Set 8 | mananara
# Processing Record 34 of Set 8 | prince rupert
# Processing Record 35 of Set 8 | tazacorte
# Processing Record 36 of Set 8 | kapsan-up
# Processing Record 37 of Set 8 | villa ojo de agua
# Processing Record 38 of Set 8 | gadzhiyevo
# Processing Record 39 of Set 8 | karratha
# Processing Record 40 of Set 8 | gamay
# Processing Record 41 of Set 8 | bodaybo
# Processing Record 42 of Set 8 | opochka
# Processing Record 43 of Set 8 | quellon
# Processing Record 44 of Set 8 | callao
# Processing Record 45 of Set 8 | rawson
# Processing Record 46 of Set 8 | onega
# Processing Record 47 of Set 8 | laramie
# Processing Record 48 of Set 8 | vorkuta
# Processing Record 49 of Set 8 | kidal
# Processing Record 0 of Set 9 | saint-pierre
# Processing Record 1 of Set 9 | beacon square
# Processing Record 2 of Set 9 | shaping
# Processing Record 3 of Set 9 | chibougamau
# Processing Record 4 of Set 9 | piti village
# Processing Record 5 of Set 9 | coquimbo
# Processing Record 6 of Set 9 | muravlenko
# Processing Record 7 of Set 9 | bedford
# Processing Record 8 of Set 9 | kapuskasing
# Processing Record 9 of Set 9 | mikuni
# Processing Record 10 of Set 9 | flying fish cove
# Processing Record 11 of Set 9 | nishinoomote
# Processing Record 12 of Set 9 | acarau
# Processing Record 13 of Set 9 | moramanga
# Processing Record 14 of Set 9 | don carlos
# Processing Record 15 of Set 9 | east london
# Processing Record 16 of Set 9 | vernon
# Processing Record 17 of Set 9 | raduzhny
# Processing Record 18 of Set 9 | grootfontein
# Processing Record 19 of Set 9 | naeso
# Processing Record 20 of Set 9 | bijie
# Processing Record 21 of Set 9 | maralal
# Processing Record 22 of Set 9 | tomatlan
# Processing Record 23 of Set 9 | magadan
# Processing Record 24 of Set 9 | bahia de caraquez
# Processing Record 25 of Set 9 | tranovaho
# City not found. Skipping...
# Processing Record 26 of Set 9 | christchurch
# Processing Record 27 of Set 9 | tura
# Processing Record 28 of Set 9 | westport
# Processing Record 29 of Set 9 | tolanaro
# Processing Record 30 of Set 9 | polyarnyy
# Processing Record 31 of Set 9 | vallenar
# Processing Record 32 of Set 9 | belozersk
# Processing Record 33 of Set 9 | kingscliff
# Processing Record 34 of Set 9 | tome acu
# Processing Record 35 of Set 9 | ad dabbah
# Processing Record 36 of Set 9 | foligno
# Processing Record 37 of Set 9 | saudarkrokur
# Processing Record 38 of Set 9 | hilo
# Processing Record 39 of Set 9 | molchanovo
# Processing Record 40 of Set 9 | al jawf
# Processing Record 41 of Set 9 | batesville
# Processing Record 42 of Set 9 | san luis de la loma
# Processing Record 43 of Set 9 | susuman
# Processing Record 44 of Set 9 | kpandu
# Processing Record 45 of Set 9 | lobujya
# Processing Record 46 of Set 9 | verdal
# Processing Record 47 of Set 9 | mbanza kongo
# Processing Record 48 of Set 9 | saldanha
# Processing Record 49 of Set 9 | ingeniero jacobacci
# Processing Record 0 of Set 10 | labrador city
# Processing Record 1 of Set 10 | mersing
# Processing Record 2 of Set 10 | mount isa
# Processing Record 3 of Set 10 | lubao
# Processing Record 4 of Set 10 | ouellah
# City not found. Skipping...
# Processing Record 5 of Set 10 | fonte boa
# Processing Record 6 of Set 10 | dauphin
# Processing Record 7 of Set 10 | bayan nur
# City not found. Skipping...
# Processing Record 8 of Set 10 | kerikeri
# Processing Record 9 of Set 10 | kill devil hills
# Processing Record 10 of Set 10 | benguela
# Processing Record 11 of Set 10 | tondano
# Processing Record 12 of Set 10 | zlatoust
# Processing Record 13 of Set 10 | lucelia
# Processing Record 14 of Set 10 | namyang
# Processing Record 15 of Set 10 | canton
# Processing Record 16 of Set 10 | chu
# Processing Record 17 of Set 10 | kawambwa
# Processing Record 18 of Set 10 | pasinler
# Processing Record 19 of Set 10 | pechora
# Processing Record 20 of Set 10 | guerrero negro
# Processing Record 21 of Set 10 | acajutla
# Processing Record 22 of Set 10 | maputo
# Processing Record 23 of Set 10 | tanumah
# Processing Record 24 of Set 10 | cefalu
# Processing Record 25 of Set 10 | tongliao
# Processing Record 26 of Set 10 | nizamabad
# Processing Record 27 of Set 10 | champerico
# Processing Record 28 of Set 10 | 'ibri
# City not found. Skipping...
# Processing Record 29 of Set 10 | tucumcari
# Processing Record 30 of Set 10 | laojunmiao
# Processing Record 31 of Set 10 | ar ruways
# Processing Record 32 of Set 10 | weligama
# Processing Record 33 of Set 10 | cargados carajos
# City not found. Skipping...
# Processing Record 34 of Set 10 | hamilton
# Processing Record 35 of Set 10 | xilin hot
# Processing Record 36 of Set 10 | sao jose da coroa grande
# Processing Record 37 of Set 10 | ifakara
# Processing Record 38 of Set 10 | pointe-du-lac
# Processing Record 39 of Set 10 | ushirombo
# Processing Record 40 of Set 10 | axim
# Processing Record 41 of Set 10 | old town
# Processing Record 42 of Set 10 | lukolela
# Processing Record 43 of Set 10 | bengkulu
# Processing Record 44 of Set 10 | estrela
# Processing Record 45 of Set 10 | piton saint-leu
# Processing Record 46 of Set 10 | colonia
# Processing Record 47 of Set 10 | eyl
# Processing Record 48 of Set 10 | pangkalanbuun
# Processing Record 49 of Set 10 | demidov
# Processing Record 0 of Set 11 | pacasmayo
# Processing Record 1 of Set 11 | mirnyy
# Processing Record 2 of Set 11 | ta`u
# Processing Record 3 of Set 11 | si sa ket
# Processing Record 4 of Set 11 | mitu
# Processing Record 5 of Set 11 | ruteng
# Processing Record 6 of Set 11 | port moresby
# Processing Record 7 of Set 11 | zhangye
# Processing Record 8 of Set 11 | waingapu
# Processing Record 9 of Set 11 | hadibu
# Processing Record 10 of Set 11 | porto novo
# Processing Record 11 of Set 11 | nanzhou
# Processing Record 12 of Set 11 | sambava
# Processing Record 13 of Set 11 | prado
# Processing Record 14 of Set 11 | qalat
# Processing Record 15 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 16 of Set 11 | huarmey
# Processing Record 17 of Set 11 | soio
# Processing Record 18 of Set 11 | mount pearl
# Processing Record 19 of Set 11 | phek
# Processing Record 20 of Set 11 | sanya
# Processing Record 21 of Set 11 | anna regina
# Processing Record 22 of Set 11 | brisas de zicatela
# Processing Record 23 of Set 11 | espargos
# City not found. Skipping...
# Processing Record 24 of Set 11 | malir cantonment
# City not found. Skipping...
# Processing Record 25 of Set 11 | peace river
# Processing Record 26 of Set 11 | azemmour
# Processing Record 27 of Set 11 | margate
# Processing Record 28 of Set 11 | klyuchi
# Processing Record 29 of Set 11 | coruripe
# Processing Record 30 of Set 11 | musoma
# Processing Record 31 of Set 11 | rawai
# Processing Record 32 of Set 11 | geraldton
# Processing Record 33 of Set 11 | sao joao da barra
# Processing Record 34 of Set 11 | gamboma
# Processing Record 35 of Set 11 | la sarre
# Processing Record 36 of Set 11 | celestun
# Processing Record 37 of Set 11 | konarka
# Processing Record 38 of Set 11 | vingt cinq
# City not found. Skipping...
# Processing Record 39 of Set 11 | santa cruz
# Processing Record 40 of Set 11 | nova xavantina
# Processing Record 41 of Set 11 | gokwe
# Processing Record 42 of Set 11 | gondar
# Processing Record 43 of Set 11 | camacupa
# Processing Record 44 of Set 11 | port douglas
# Processing Record 45 of Set 11 | gadsden
# Processing Record 46 of Set 11 | chipata
# Processing Record 47 of Set 11 | awjilah
# Processing Record 48 of Set 11 | zelenoborskiy
# Processing Record 49 of Set 11 | kranuan
# Processing Record 0 of Set 12 | coaraci
# Processing Record 1 of Set 12 | kyzyl-suu
# Processing Record 2 of Set 12 | saint-francois
# Processing Record 3 of Set 12 | libreville
# Processing Record 4 of Set 12 | constitucion
# Processing Record 5 of Set 12 | nyagan
# Processing Record 6 of Set 12 | zeya
# Processing Record 7 of Set 12 | carnarvon
# Processing Record 8 of Set 12 | sansanne-mango
# Processing Record 9 of Set 12 | akureyri
# Processing Record 10 of Set 12 | sao paulo de olivenca
# Processing Record 11 of Set 12 | smithers
# Processing Record 12 of Set 12 | tsiombe
# Processing Record 13 of Set 12 | barclayville
# Processing Record 14 of Set 12 | touros
# Processing Record 15 of Set 12 | aranda de duero
# Processing Record 16 of Set 12 | enshi
# Processing Record 17 of Set 12 | sur
# Processing Record 18 of Set 12 | esperanza
# Processing Record 19 of Set 12 | paita
# Processing Record 20 of Set 12 | alto araguaia
# Processing Record 21 of Set 12 | felege neway
# Processing Record 22 of Set 12 | qapqal
# City not found. Skipping...
# Processing Record 23 of Set 12 | santo antonio
# Processing Record 24 of Set 12 | sarangani
# Processing Record 25 of Set 12 | devinuwara
# City not found. Skipping...
# Processing Record 26 of Set 12 | chul'man
# Processing Record 27 of Set 12 | ke-macina
# Processing Record 28 of Set 12 | batticaloa
# Processing Record 29 of Set 12 | bima
# Processing Record 30 of Set 12 | vicuna mackenna
# Processing Record 31 of Set 12 | dzuunmod
# Processing Record 32 of Set 12 | huatabampo
# Processing Record 33 of Set 12 | kruisfontein
# Processing Record 34 of Set 12 | hammerfest
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          557
# Lat           557
# Lng           557
# Max Temp      557
# Humidity      557
# Cloudiness    557
# Wind Speed    557
# Country       557
# Date          557
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       roma  43.2128 -75.4557     33.37        97         100        5.75
# 1  castillos -34.1667 -53.8333     72.01        91           3        7.94
# 2  dahlonega  34.5326 -83.9849     49.93        82           0        3.74
# 3     harper   4.3750  -7.7169     77.18        87          95        2.48
# 4   la passe  45.5549  -0.8967     40.30        77           0        4.81
#
#   Country        Date
# 0      US  1738644755
# 1      UY  1738644756
# 2      US  1738644481
# 3      LR  1738644758
# 4      FR  1738644760

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             roma  43.2128 -75.4557     33.37        97         100
# 1        castillos -34.1667 -53.8333     72.01        91           3
# 2        dahlonega  34.5326 -83.9849     49.93        82           0
# 3           harper   4.3750  -7.7169     77.18        87          95
# 4         la passe  45.5549  -0.8967     40.30        77           0
#
#          Wind Speed Country        Date
# City_ID
# 0              5.75      US  1738644755
# 1              7.94      UY  1738644756
# 2              3.74      US  1738644481
# 3              2.48      LR  1738644758
# 4              4.81      FR  1738644760

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolors="black")

# Incorporate the other graph properties
plt.title(f"City Latitude vs Max Temperature ({pd.to_datetime(city_data_df['Date'], unit='s').dt.strftime('%Y-%m-%d').max()})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolors="black")

# Incorporate the other graph properties
plt.title(f"City Latitude vs Humidity ({pd.to_datetime(city_data_df['Date'], unit='s').dt.strftime('%Y-%m-%d').max()})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolors="black")

# Incorporate the other graph properties
plt.title(f"City Latitude vs Cloudiness ({pd.to_datetime(city_data_df['Date'], unit='s').dt.strftime('%Y-%m-%d').max()})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolors="black")

# Incorporate the other graph properties
plt.title(f"City Latitude vs Wind Speed ({pd.to_datetime(city_data_df['Date'], unit='s').dt.strftime('%Y-%m-%d').max()})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linregress_plot(x_values,y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    print(f"The r^2-value is:{rvalue**2}")
    plt.scatter(x_values, y_values, edgecolors = "black", linewidth=0.5)
    plt.plot(x_values, regress_values, "r")
    plt.annotate(line_eq,(x_values.min(), y_values.min()), fontsize=13)
    plt.tight_layout()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0, :]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             roma  43.2128 -75.4557     33.37        97         100
# 2        dahlonega  34.5326 -83.9849     49.93        82           0
# 3           harper   4.3750  -7.7169     77.18        87          95
# 4         la passe  45.5549  -0.8967     40.30        77           0
# 5        dickinson  29.4608 -95.0513     72.05        90         100
#
#          Wind Speed Country        Date
# City_ID
# 0              5.75      US  1738644755
# 2              3.74      US  1738644481
# 3              2.48      LR  1738644758
# 4              4.81      FR  1738644760
# 5             10.36      US  1738644761

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0, :]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1                castillos -34.1667  -53.8333     72.01        91           3
# 6        port-aux-francais -49.3500   70.2167     40.87        81          99
# 8                grytviken -54.2811  -36.5092     42.08        85          69
# 9           port macquarie -31.4333  152.9167     80.08        77         100
# 13            puerto ayora  -0.7393  -90.3518     75.54        94          33
#
#          Wind Speed Country        Date
# City_ID
# 1              7.94      UY  1738644756
# 6             22.57      TF  1738644762
# 8             25.05      GS  1738644764
# 9              7.00      AU  1738644765
# 13             4.25      EC  1738644769

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linregress_plot(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])
plt.title("Latitude vs Max Temp")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")

plt.show()
# Out:
# The r^2-value is:0.8047211869456711

# %%
# Linear regression on Southern Hemisphere
linregress_plot(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])
plt.title("Latitude vs Max Temp")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")

plt.show()
# Out:
# The r^2-value is:0.25331009565734186

# %% [markdown]
# **Discussion about the linear relationship:** Looking at both the northern and southern hemispheres, the closer you are to the equator, the warmer the temperatures are going to be.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linregress_plot(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])
plt.title("Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

plt.show()
# Out:
# The r^2-value is:0.17337594662365827

# %%
#Southern Hemisphere
linregress_plot(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])
plt.title("Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

plt.show()
# Out:
# The r^2-value is:0.04908058148849911

# %% [markdown]
# **Discussion about the linear relationship:** According to r squared values for both hemispheres, it is pretty low. So this means that humidity does not play a large role in regards to how close we are to the equator.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linregress_plot(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])
plt.title("Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

plt.show()
# Out:
# The r^2-value is:0.0337757699445707

# %%
# Southern Hemisphere
linregress_plot(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"])
plt.title("Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

plt.show()
# Out:
# The r^2-value is:0.19936344916521703

# %% [markdown]
# **Discussion about the linear relationship:** Similar to humidity, cloudiness does not seem to vary depending on how close we are to the equator.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linregress_plot(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"])
plt.title("Latitude vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

plt.show()
# Out:
# The r^2-value is:0.004033330572521418

# %%
# Southern Hemisphere
linregress_plot(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"])
plt.title("Latitude vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Southern Hemisphere
# ----> 2 linregress_plot(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"])
#       3 plt.title("Latitude vs Wind Speed")
#       4 plt.xlabel("Latitude")
#
# NameError: name 'linregress_plot' is not defined

# %% [markdown]
# **Discussion about the linear relationship:** Wind speed does not seem to vary depending on how close we are to the equator no matter the hemisphere. The r squared values for both are pretty low.
